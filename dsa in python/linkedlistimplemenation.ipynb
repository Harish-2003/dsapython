# %%
#code from prepinsta
class Node:
    def __init__(self, data):
        self.data = data 
        self.next = None 
class LinkedList: 
    def __init__(self): 
        self.head = None 
 
    def insertStart(self, data):
        new_node = Node (data) 
        new_node.next = self.head 
  
        #changing the head to freshly entered node
        self.head = new_node 
 
    def insertLast(self, data):
        new_node = Node (data) 
  
        new_node.next = None 
 
        #need this if there is no node present in linked list at all
        if self.head is None:
            self.head = new_node 
            return 
 
        temp = self.head 
 
        while temp.next is not None: 
            temp = temp.next 
 
        temp.next = new_node 
    
    def insertPosition (self, pos, data):
        size = self.calcSize () 
        if pos<1 or size<pos:
            print ("Can't insert", pos," is not valid position") 
        else:
            temp = self.head 
            new_node = Node (data) 

        for i in range(1, pos): 
            temp = temp.next 
            pos -= 1 
 
        new_node.next = temp.next 
        temp.next = new_node 

    def display(self) :
        temp = self.head 
        while temp : 
            print (temp.data, end = " ") 
            temp = temp.next 
 
    def calcSize(self):
        size = 0 
        node =self.head 

        while node is not None:
            node = node.next 
            size +=1 
        return size 
 
#Drive Code
ll = LinkedList() 

ll.insertStart(12) 
ll.insertStart(16) 
ll.insertStart(20) 

ll.insertLast(10) 
ll.insertLast(14) 
ll.insertLast(18) 
ll.insertLast(11) 
 
#Inserts after 3rd position
ll.insertPosition(3, 25)
ll.display()
# Out:
# 20 16 12 25 10 14 18 11

# %% [markdown]
# #inserelements at the start of the linked list

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class LinkedList:
    def __init__(self):
        self.headval=None
    def insertelement(self,data):
        new_node=Node(data)    #new node is created # u gonna understand this when we take two nodes as examples
                                  # at first a node is created and the adresss is assigned with the none adress
                                 #and then at line 16 the headval is assigned with the node that is created
                               # after creating the first node then the first node is represented as head of the linked list
                                # as on the next step headval is not none which makes the new node to adress the node before and 
                                                    #on the next line the value is changes
        new_node.nextval=self.headval  #but in this case we are assigining the value of the nextval to the headval as first
        self.headval=new_node
    def listprint(self):
        printval=self.headval
        while(printval is not None):
            print(printval.data)
            printval=printval.nextval
li=LinkedList()
li.insertelement(10)
li.insertelement(20)
li.insertelement(30)
li.listprint()
# Out:
# 30
# 20
# 10

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class LinkedList:
    def __init__(self):
        self.headval=None
    def insertlast(self,data):
        newnode=Node(data)
        if(self.headval is None):
            self.headval=newnode
                  # in insert last we are not inseting elements at the head but at the last where the value is none
        temp=self.headval
        while(temp.nextval is not None):
            temp=temp.nextval
        temp.nextval=newnode    
    def listprint(self):
        printval=self.headval
        while(printval is not None):
            print(printval.data)
            printval=printval.nextval
li=LinkedList()
li.insertlast(10)
li.insertlast(30)
li.listprint()

# %% [raw]
# #insert in between the linked list

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class LinkedList:
    def __init__(self):
        self.headval=None
    def insertelement(self,data):
        new_node=Node(data)    #new node is created # u gonna understand this when we take two nodes as examples
                                  # at first a node is created and the adresss is assigned with the none adress
                                 #and then at line 16 the headval is assigned with the node that is created
                               # after creating the first node then the first node is represented as head of the linked list
                                # as on the next step headval is not none which makes the new node to adress the node before and 
                                                    #on the next line the value is changes
        new_node.nextval=self.headval  #but in this case we are assigining the value of the nextval to the headval as first
        self.headval=new_node
    def listprint(self):
        printval=self.headval
        while(printval is not None):
            print(printval.data)
            printval=printval.nextval
li=LinkedList()
li.insertelement(10)
li.insertelement(20)
li.insertelement(30)
li.listprint()

#this code gives infinite loop
# Out:
# 30
# 20
# 10

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class LinkedList:
    def __init__(self):
        self.headval=None
    def insertelement(self,data):
        new_node=Node(data)    #new node is created
        new_node.nextval=self.headval  #but in this case we are assigining the value of the nextval to the headval as first
        self.headval=new_node
        
    def lastelement(self,data):
        new_node=Node(data)
        if(self.headval is None):
            self.headval=new_node
            return
        last=self.headval
        while(last is not None):
            last=last.nextval
        last.nextval=Node(data)
    def listprint(self):
        printval=self.headval
        while(printval is not None):
            print(printval.data)
            printval=printval.nextval
li=LinkedList()

li.listprint()

#this code gives infinite loop

# %%
#inserting element to the last
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class LinkedList:
    def __init__(self):
        self.headval=None
  #~~~~~~~to insert element at the last position  ~~~~~~~~~~~~~~~~~
    def lastelement(self,data):
        new_node=Node(data)
        new_node.next=None
        if(self.headval is None):
            self.headval=new_node
            return
        else:
            temp=self.headval
            while(temp is not None):
                temp=temp.nextval
            temp.next=new_node
            
    #~~~~~~~~~~~to insert element in the between the position of the list
    def printvalues(self):
        temp=self.head
        while(temp):
            print(temp.data,end=" ")
            temp=temp.next

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class LinkedList:
    def __init__(self):
        self.headval=None
    def insertelement(self,data):
        new_node=Node(data)    #new node is created
        self.headval=new_node
        new_node.nextval=self.headval 
  #here we are assigning the same adress of the that node to that node which makes our code to run in infinite loop
    def listprint(self):
        printval=self.headval
        while(printval is not None):
            print(printval.data)
            printval=printval.nextval
li=LinkedList()
li.insertelement(10)
li.insertelement(20)
li.insertelement(30)
li.listprint()

#this code gives infinite loop

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.nextval=None
class Linkedlist:
    def __init__(self):
        self.head=None
    def insertstart(self,data):
        node=Node(data)
        node.nextval=self.head
        self.head=Node

# %%
class Node:
    def __init__(self,data):
        self.next=None
        self.data=data
#the above thing helps to create a node with a data and a adresses
class Linked:
    def __init__(self):
        self.head=None
    def insert(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
    def end(self,data):
        z=self.head
        while z.next is not None:
            z=z.next
        z.next=Node(data)
    def display(self):
        z=self.head
        while(z):
            print(z.data)
            z=z.next
k=Linked()
k.insert(5)
k.insert(7)
k.end(2)
k.display()
# Out:
# 7
# 5
# 2

# %%
#print the linked list in the reversed manner
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class Linked:
    def __init__(self):
        self.head=None
    def insert(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
    def reversedisplay(self):
        k=self.head
        z=[]
        while(k is not None):
            z.append(k.data)
            k=k.next
        return z[::-1]
k=Linked()
k.insert(5)
k.insert(9)
alpha=k.reversedisplay()
print(alpha)
# Out:
# [5, 9]
